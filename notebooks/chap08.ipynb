# %% [markdown]
# You can order print and ebook versions of *Think Python 3e* from
# [Bookshop.org](https://bookshop.org/a/98697/9781098155438) and
# [Amazon](https://www.amazon.com/_/dp/1098155432?smid=ATVPDKIKX0DER&_encoding=UTF8&tag=oreilly20-20&_encoding=UTF8&tag=greenteapre01-20&linkCode=ur2&linkId=e2a529f94920295d27ec8a06e757dc7c&camp=1789&creative=9325).

# %% [markdown]
# # Strings and Regular Expressions
#
# Strings are not like integers, floats, and booleans. A string is a **sequence**, which means it contains multiple values in a particular order.
# In this chapter we'll see how to access the values that make up a string, and we'll use functions that process strings.
#
# We'll also use regular expressions, which are a powerful tool for finding patterns in a string and performing operations like search and replace.
#
# As an exercise, you'll have a chance to apply these tools to a word game called Wordle.

# %% [markdown]
# ## A string is a sequence
#
# A string is a sequence of characters. A **character** can be a letter (in almost any alphabet), a digit, a punctuation mark, or white space.
#
# You can select a character from a string with the bracket operator.
# This example statement selects character number 1 from `fruit` and
# assigns it to `letter`:

# %%
animal = 'dog'
letter = animal[2]

# %% [markdown]
# The expression in brackets is an **index**, so called because it *indicates* which character in the sequence to select.
# But the result might not be what you expect.

# %%
letter
# Out:
# 'g'

# %% [markdown]
# The letter with index `1` is actually the second letter of the string.
# An index is an offset from the beginning of the string, so the offset of the first letter is `0`.

# %%
animal[0]
# Out:
# 'd'

# %% [markdown]
# You can think of `'b'` as the 0th letter of `'banana'` -- pronounced "zero-eth".
#
# The index in brackets can be a variable.

# %%
i = 2
animal[i]
# Out:
# 'g'

# %% [markdown]
# Or an expression that contains variables and operators.

# %%
animal[i+0]
# Out:
# 'g'

# %% [markdown]
# But the value of the index has to be an integer -- otherwise you get a `TypeError`.

# %%
animal[0.5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 animal[0.5]
#
# TypeError: string indices must be integers, not 'float'

# %% [markdown]
# As we saw in Chapter 1, we can use the built-in function `len` to get the length of a string.

# %%
n = len(animal)
n
# Out:
# 3

# %% [markdown]
# To get the last letter of a string, you might be tempted to write this:

# %%
animal[n]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 animal[n]
#
# IndexError: string index out of range

# %% [markdown]
# But that causes an `IndexError` because there is no letter in `'banana'` with the index 6. Because we started counting at `0`, the six letters are numbered `0` to `5`. To get the last character, you have to subtract `1` from `n`:

# %%
animal[n-1]
# Out:
# 'g'

# %% [markdown]
# But there's an easier way.
# To get the last letter in a string, you can use a negative index, which counts backward from the end.

# %%
animal[-1]
# Out:
# 'g'

# %% [markdown]
# The index `-1` selects the last letter, `-2` selects the second to last, and so on.

# %% [markdown]
# ## String slices
#
# A segment of a string is called a **slice**.
# Selecting a slice is similar to selecting a character.

# %%
animal = 'dog'
animal[1:2]
# Out:
# 'o'

# %% [markdown]
# The operator `[n:m]` returns the part of the string from the `n`th
# character to the `m`th character, including the first but excluding the second.
# This behavior is counterintuitive, but it might help to imagine the indices pointing *between* the characters, as in this figure:

# %% [markdown]
# For example, the slice `[3:6]` selects the letters `ana`, which means that `6` is legal as part of a slice, but not legal as an index.
#
#
# If you omit the first index, the slice starts at the beginning of the string.

# %%
animal[:2]
# Out:
# 'do'

# %% [markdown]
# If you omit the second index, the slice goes to the end of the string:

# %%
animal[2:]
# Out:
# 'g'

# %% [markdown]
# If the first index is greater than or equal to the second, the result is an **empty string**, represented by two quotation marks:

# %%
animal[2:2]
# Out:
# ''

# %% [markdown]
# An empty string contains no characters and has length 0.
#
# Continuing this example, what do you think `fruit[:]` means? Try it and
# see.

# %%
animal[:]
# Out:
# 'dog'

# %% [markdown]
# ## Strings are immutable
#
# It is tempting to use the `[]` operator on the left side of an
# assignment, with the intention of changing a character in a string, like this:

# %%
goodbye = 'best wishes'
goodbye[0] = 'R'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 goodbye = 'best wishes'
# ----> 2 goodbye[0] = 'R'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# The result is a `TypeError`.
# In the error message, the "object" is the string and the "item" is the character
# we tried to assign.
# For now, an **object** is the same thing as a value, but we will refine that definition later.
#
# The reason for this error is that strings are **immutable**, which means you can't change an existing string.
# The best you can do is create a new string that is a variation of the original.

# %%
new_goodbye = 'R' + goodbye[1:]
new_goodbye
# Out:
# 'Rest wishes'

# %% [markdown]
# This example concatenates a new first letter onto a slice of `greeting`.
# It has no effect on the original string.

# %%
goodbye
# Out:
# 'best wishes'

# %% [markdown]
# ## String comparison
#
# The relational operators work on strings. To see if two strings are
# equal, we can use the `==` operator.

# %%
word = 'food'

if word == 'food':
    print('Yay, food.')
# Out:
# Yay, food.

# %% [markdown]
# Other relational operations are useful for putting words in alphabetical
# order:

# %%
def compare_word(word):
    if word < 'food':
        print(word, 'is before food.')
    elif word > 'food':
        print(word, 'is after food.')
    else:
        print('Yay, food.')

# %%
compare_word('drink')
# Out:
# drink is before food.

# %% [markdown]
# Python does not handle uppercase and lowercase letters the same way
# people do. All the uppercase letters come before all the lowercase
# letters, so:

# %%
compare_word('Ice cream')
# Out:
# Ice cream is before food.

# %% [markdown]
# To solve this problem, we can convert strings to a standard format, such as all lowercase, before performing the comparison.
# Keep that in mind if you have to defend yourself against a man armed with a Pineapple.

# %% [markdown]
# ## String methods
#
# Strings provide methods that perform a variety of useful operations.
# A method is similar to a function -- it takes arguments and returns a value -- but the syntax is different.
# For example, the method `upper` takes a string and returns a new string with all uppercase letters.
#
# Instead of the function syntax `upper(word)`, it uses the method syntax `word.upper()`.

# %%
word = 'food'
new_word = word.upper()
new_word
# Out:
# 'FOOD'

# %% [markdown]
# This use of the dot operator specifies the name of the method, `upper`, and the name of the string to apply the method to, `word`.
# The empty parentheses indicate that this method takes no arguments.
#
# A method call is called an **invocation**; in this case, we would say that we are invoking `upper` on `word`.

# %% [markdown]
# ## Writing files
#
# String operators and methods are useful for reading and writing text files.
# As an example, we'll work with the text of *Dracula*, a novel by Bram Stoker that is available from Project Gutenberg (<https://www.gutenberg.org/ebooks/345>).

# %% [markdown]
# I've downloaded the book in a plain text file called `pg345.txt`, which we can open for reading like this:

# %%
reader = open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345.txt')

# %% [markdown]
# In addition to the text of the book, this file contains a section at the beginning with information about the book and a section at the end with information about the license.
# Before we process the text, we can remove this extra material by finding the special lines at the beginning and end that begin with `'***'`.
#
# The following function takes a line and checks whether it is one of the special lines.
# It uses the `startswith` method, which checks whether a string starts with a given sequence of characters.

# %%
def is_special_line(line):
    return line.startswith('*** ')

# %% [markdown]
# We can use this function to loop through the lines in the file and print only the special lines.

# %%
for line in reader:
    if is_special_line(line):
        print(line.strip())
# Out:
# *** START OF THE PROJECT GUTENBERG EBOOK DRACULA ***
# *** END OF THE PROJECT GUTENBERG EBOOK DRACULA ***

# %% [markdown]
# Now let's create a new file, called `pg345_cleaned.txt`, that contains only the text of the book.
# In order to loop through the book again, we have to open it again for reading.
# And, to write a new file, we can open it for writing.

# %%
reader = open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345.txt')
writer = open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_cleaned.txt', 'w')

# %% [markdown]
# `open` takes an optional parameters that specifies the "mode" -- in this example, `'w'` indicates that we're opening the file for writing.
# If the file doesn't exist, it will be created; if it already exists, the contents will be replaced.
#
# As a first step, we'll loop through the file until we find the first special line.

# %%
for line in reader:
    if is_special_line(line):
        break

# %% [markdown]
# The `break` statement "breaks" out of the loop -- that is, it causes the loop to end immediately, before we get to the end of the file.
#
# When the loop exits, `line` contains the special line that made the conditional true.

# %%
line
# Out:
# '*** START OF THE PROJECT GUTENBERG EBOOK DRACULA ***\n'

# %% [markdown]
# Because `reader` keeps track of where it is in the file, we can use a second loop to pick up where we left off.
#
# The following loop reads the rest of the file, one line at a time.
# When it finds the special line that indicates the end of the text, it breaks out of the loop.
# Otherwise, it writes the line to the output file.

# %%
for line in reader:
    if is_special_line(line):
        break
    writer.write(line)

# %% [markdown]
# When this loop exits, `line` contains the second special line.

# %%
line
# Out:
# '*** END OF THE PROJECT GUTENBERG EBOOK DRACULA ***\n'

# %% [markdown]
# At this point `reader` and `writer` are still open, which means we could keep reading lines from `reader` or writing lines to `writer`.
# To indicate that we're done, we can close both files by invoking the `close` method.

# %%
reader.close()
writer.close()

# %% [markdown]
# To check whether this process was successful, we can read the first few lines from the new file we just created.

# %%
for line in open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_cleaned.txt'):
    line = line.strip()
    if len(line) > 0:
        print(line)
    if line.endswith('Stoker'):
        break
# Out:
# DRACULA
# _by_
# Bram Stoker

# %% [markdown]
# The `endswidth` method checks whether a string ends with a given sequence of characters.

# %% [markdown]
# ## Find and replace
#
# In the Icelandic translation of *Dracula* from 1901, the name of one of the characters was changed from "Jonathan" to "Thomas".
# To make this change in the English version, we can loop through the book, use the `replace` method to replace one name with another, and write the result to a new file.
#
# We'll start by counting the lines in the cleaned version of the file.

# %%
total = 0
for line in open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_cleaned.txt'):
    total += 1
total
# Out:
# 15475

# %% [markdown]
# To see whether a line contains "Jonathan", we can use the `in` operator, which checks whether this sequence of characters appears anywhere in the line.

# %%
total = 0
for line in open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_cleaned.txt'):
    if 'Jonathan' in line:
        total += 1
total
# Out:
# 199

# %% [markdown]
# There are 199 lines that contain the name, but that's not quite the total number of times it appears, because it can appear more than once in a line.
# To get the total, we can use the `count` method, which returns the number of times a sequence appears in a string.

# %%
total = 0
for line in open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_cleaned.txt'):
    total += line.count('Jonathan')

total
# Out:
# 200

# %% [markdown]
# Now we can replace `'Jonathan'` with `'Thomas'` like this:

# %%
writer = open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_replaced.txt', 'w')

for line in open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_cleaned.txt'):
    line = line.replace('Jonathan', 'William')
    writer.write(line)

# %% [markdown]
# The result is a new file called `pg345_replaced.txt` that contains a version of *Dracula* where Jonathan Harker is called Thomas.

# %% [markdown]
# ## Regular expressions
#
# If we know exactly what sequence of characters we're looking for, we can use the `in` operator to find it and the `replace` method to replace it.
# But there is another tool, called a **regular expression** that can also perform these operations -- and a lot more.
#
# To demonstrate, I'll start with a simple example and we'll work our way up.
# Suppose, again, that we want to find all lines that contain a particular word.
# For a change, let's look for references to the titular character of the book, Count Dracula.
# Here's a line that mentions him.

# %%
text = "I am Dracula; and I bid you welcome, Mr. Harker, to my house."

# %% [markdown]
# And here's the **pattern** we'll use to search.

# %%
pattern = 'Dracula'

# %% [markdown]
# A module called `re` provides functions related to regular expressions.
# We can import it like this and use the `search` function to check whether the pattern appears in the text.

# %%
import re

result = re.search(pattern, text)
result
# Out:
# <re.Match object; span=(5, 12), match='Dracula'>

# %% [markdown]
# If the pattern appears in the text, `search` returns a `Match` object that contains the results of the search.
# Among other information, it has a variable named `string` that contains the text that was searched.

# %%
result.string
# Out:
# 'I am Dracula; and I bid you welcome, Mr. Harker, to my house.'

# %% [markdown]
# It also provides a method called `group` that returns the part of the text that matched the pattern.

# %%
result.group()
# Out:
# 'Dracula'

# %% [markdown]
# And it provides a method called `span` that returns the index in the text where the pattern starts and ends.

# %%
result.span()
# Out:
# (5, 12)

# %% [markdown]
# If the pattern doesn't appear in the text, the return value from `search` is `None`.

# %%
result = re.search('Count', text)
print(result)
# Out:
# None

# %% [markdown]
# So we can check whether the search was successful by checking whether the result is `None`.

# %%
result == None
# Out:
# True

# %% [markdown]
# Putting all that together, here's a function that loops through the lines in the book until it finds one that matches the given pattern, and returns the `Match` object.

# %%
def find_first(pattern):
    for line in open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_cleaned.txt'):
        result = re.search(pattern, line)
        if result != None:
            return result

# %% [markdown]
# We can use it to find the first mention of a character.

# %%
result = find_first('Harker')
result.string
# Out:
# 'CHAPTER I. Jonathan Harker’s Journal\n'

# %% [markdown]
# For this example, we didn't have to use regular expressions -- we could have done the same thing more easily with the `in` operator.
# But regular expressions can do things the `in` operator cannot.
#
# For example, if the pattern includes the vertical bar character, `'|'`, it can match either the sequence on the left or the sequence on the right.
# Suppose we want to find the first mention of Mina Murray in the book, but we are not sure whether she is referred to by first name or last.
# We can use the following pattern, which matches either name.

# %%
pattern = 'Mina|Murray'
result = find_first(pattern)
result.string
# Out:
# 'CHAPTER V. Letters—Lucy and Mina\n'

# %% [markdown]
# We can use a pattern like this to see how many times a character is mentioned by either name.
# Here's a function that loops through the book and counts the number of lines that match the given pattern.

# %%
def count_matches(pattern):
    count = 0
    for line in open('C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\\data\pg345_cleaned.txt'):
        result = re.search(pattern, line)
        if result != None:
            count += 1
    return count

# %% [markdown]
# Now let's see how many times Mina is mentioned.

# %%
count_matches('Mina|Murray')
# Out:
# 229

# %% [markdown]
# The special character `'^'` matches the beginning of a string, so we can find a line that starts with a given pattern.

# %%
result = find_first('^Dracula')
result.string
# Out:
# 'Dracula, jumping to his feet, said:--\n'

# %% [markdown]
# And the special character `'$'` matches the end of a string, so we can find a line that ends with a given pattern (ignoring the newline at the end).

# %%
result = find_first('Harker$')
result.string
# Out:
# 'by five o’clock, we must start off; for it won’t do to leave Mrs. Harker\n'

# %% [markdown]
# ## String substitution
#
# Bram Stoker was born in Ireland, and when *Dracula* was published in 1897, he was living in England.
# So we would expect him to use the British spelling of words like "centre" and "colour".
# To check, we can use the following pattern, which matches either "centre" or the American spelling "center".

# %%
pattern = 'cent(er|re)'

# %% [markdown]
# In this pattern, the parentheses enclose the part of the pattern the vertical bar applies to.
# So this pattern matches a sequence that starts with `'cent'` and ends with either `'er'` or `'re'`.

# %%
result = find_first(pattern)
result.string
# Out:
# 'horseshoe of the Carpathians, as if it were the centre of some sort of\n'

# %% [markdown]
# As expected, he used the British spelling.
#
# We can also check whether he used the British spelling of "colour".
# The following pattern uses the special character `'?'`, which means that the previous character is optional.

# %%
pattern = 'colou?r'

# %% [markdown]
# This pattern matches either "colour" with the `'u'` or "color" without it.

# %%
result = find_first(pattern)
line = result.string
line
# Out:
# 'undergarment with long double apron, front, and back, of coloured stuff\n'

# %% [markdown]
# Again, as expected, he used the British spelling.
#
# Now suppose we want to produce an edition of the book with American spellings.
# We can use the `sub` function in the `re` module, which does **string substitution**.

# %%
re.sub(pattern, 'color', line)
# Out:
# 'undergarment with long double apron, front, and back, of colored stuff\n'

# %% [markdown]
# The first argument is the pattern we want to find and replace, the second is what we want to replace it with, and the third is the string we want to search.
# In the result, you can see that "colour" has been replaced with "color".

# %% [markdown]
# ## Debugging
#
# When you are reading and writing files, debugging can be tricky.
# If you are working in a Jupyter notebook, you can use **shell commands** to help.
# For example, to display the first few lines of a file, you can use the command `!head`, like this:

# %%
# !powershell -command "Get-Content C:\Users\nmolendyk1\Documents\GitHub\oim3640\data\pg345_cleaned.txt -Head 5"
# Out:
#                                 DRACULA
# . : File C:\Users\nmolendyk1\Documents\WindowsPowerShell\profile.ps1 cannot be loaded because running scripts is
# disabled on this system. For more information, see about_Execution_Policies at
# https:/go.microsoft.com/fwlink/?LinkID=135170.
# At line:1 char:3
# + . 'C:\Users\nmolendyk1\Documents\WindowsPowerShell\profile.ps1'
# +   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : SecurityError: (:) [], PSSecurityException
#     + FullyQualifiedErrorId : UnauthorizedAccess

# %% [markdown]
# The initial exclamation point, `!`, indicates that this is a shell command, which is not part of Python.
# To display the last few lines, you can use `!tail`.

# %%
# !powershell -command "Get-Content C:\Users\nmolendyk1\Documents\GitHub\oim3640\data\pg345_cleaned.txt -Tail 5"
# Out:
# GROSSET & DUNLAP, _Publishers_, NEW YORK
# . : File C:\Users\nmolendyk1\Documents\WindowsPowerShell\profile.ps1 cannot be loaded because running scripts is
# disabled on this system. For more information, see about_Execution_Policies at
# https:/go.microsoft.com/fwlink/?LinkID=135170.
# At line:1 char:3
# + . 'C:\Users\nmolendyk1\Documents\WindowsPowerShell\profile.ps1'
# +   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#     + CategoryInfo          : SecurityError: (:) [], PSSecurityException
#     + FullyQualifiedErrorId : UnauthorizedAccess

# %% [markdown]
# When you are working with large files, debugging can be difficult because there might be too much output to check by hand.
# A good debugging strategy is to start with just part of the file, get the program working, and then run it with the whole file.
#
# To make a small file that contains part of a larger file, we can use `!head` again with the redirect operator, `>`, which indicates that the results should be written to a file rather than displayed.

# %%
# !head pg345_cleaned.txt > pg345_cleaned_100_lines.txt

# %% [markdown]
# By default, `!head` reads the first 10 lines, but it takes an optional argument that indicates the number of lines to read.

# %%
# !head -100 pg345_cleaned.txt > pg345_cleaned_100_lines.txt
# Out:
# 'head' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# This shell command reads the first 100 lines from `pg345_cleaned.txt` and writes them to a file called `pg345_cleaned_100_lines.txt`.
#
# Note: The shell commands `!head` and `!tail` are not available on all operating systems.
# If they don't work for you, we can write similar functions in Python.
# See the first exercise at the end of this chapter for suggestions.

# %% [markdown]
# ## Glossary
#
# **sequence:**
#  An ordered collection of values where each value is identified by an integer index.
#
# **character:**
# An element of a string, including letters, numbers, and symbols.
#
# **index:**
#  An integer value used to select an item in a sequence, such as a character in a string. In Python indices start from `0`.
#
# **slice:**
#  A part of a string specified by a range of indices.
#
# **empty string:**
# A string that contains no characters and has length `0`.
#
# **object:**
#  Something a variable can refer to. An object has a type and a value.
#
# **immutable:**
# If the elements of an object cannot be changed, the object is immutable.
#
# **invocation:**
#  An expression -- or part of an expression -- that calls a method.
#
# **regular expression:**
# A sequence of characters that defines a search pattern.
#
# **pattern:**
# A rule that specifies the requirements a string has to meet to constitute a match.
#
# **string substitution:**
# Replacement of a string, or part of a string, with another string.
#
# **shell command:**
# A statement in a shell language, which is a language used to interact with an operating system.

# %% [markdown]
# ## Exercises

# %% [markdown]
# ### Ask a virtual assistant
#
# In this chapter, we only scratched the surface of what regular expressions can do.
# To get an idea of what's possible, ask a virtual assistant, "What are the most common special characters used in Python regular expressions?"
#
# You can also ask for a pattern that matches particular kinds of strings.
# For example, try asking:
#
# * Write a Python regular expression that matches a 10-digit phone number with hyphens.
#
# * Write a Python regular expression that matches a street address with a number and a street name, followed by `ST` or `AVE`.
#
# * Write a Python regular expression that matches a full name with any common title like `Mr` or `Mrs` followed by any number of names beginning with capital letters, possibly with hyphens between some names.
#
# And if you want to see something more complicated, try asking for a regular expression that matches any legal URL.
#
# A regular expression often has the letter `r` before the quotation mark, which indicates that it is a "raw string".
# For more information, ask a virtual assistant, "What is a raw string in Python?"

# %% [markdown]
# ### Exercise
#
# See if you can write a function that does the same thing as the shell command `!head`.
# It should take as arguments the name of a file to read, the number of lines to read, and the name of the file to write the lines into.
# If the third parameter is `None`, it should display the lines rather than write them to a file.
#
# Consider asking a virtual assistant for help, but if you do, tell it not to use a `with` statement or a `try` statement.

# %%
def head(filename_read, read_lines, filename_write):
    reader = open(filename_read)
    
    if filename_write is None:
        for i in range(read_lines):
            line = reader.readline()
            print(line.strip())
        else:
            writer = open(filename_write, 'w')
            for i in range(read_lines):
                line = reader.readline()
                writer.write(line)
            writer.close()
        
        reader.close()

# %% [markdown]
# You can use the following examples to test your function.

# %%
head("C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\data\pg345.txt", 5, None)
# Out:
# The Project Gutenberg eBook of Dracula
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 head("C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\data\pg345.txt", 5, None)
#
# Cell In[16], line 9, in head(filename_read, read_lines, filename_write)
#       7     print(line.strip())
#       8 else:
# ----> 9     writer = open(filename_write, 'w')
#      10     for i in range(read_lines):
#      11         line = reader.readline()
#
# File c:\Users\nmolendyk1\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %% [markdown]
# ### Exercise
#
# "Wordle" is an online word game where the objective is to guess a five-letter word in six or fewer attempts.
# Each attempt has to be recognized as a word, not including proper nouns.
# After each attempt, you get information about which of the letters you guessed appear in the target word, and which ones are in the correct position.
#
# For example, suppose the target word is `MOWER` and you guess `TRIED`.
# You would learn that `E` is in the word and in the correct position, `R` is in the word but not in the correct position, and `T`, `I`, and `D` are not in the word.
#
# As a different example, suppose you have guessed the words `SPADE` and `CLERK`, and you've learned that `E` is in the word, but not in either of those positions, and none of the other letters appear in the word.
# Of the words in the word list, how many could be the target word?
# Write a function called `check_word` that takes a five-letter word and checks whether it could be the target word, given these guesses.

# %%
def check_word(word):
    word = word.upper()

    if len(word) != 5:
        return False
    
    forbidden_letters = ['S', 'P', 'A', 'D', 'C', 'L', 'R', 'K']

    if any(letter in forbidden_letters for letter in word):
        return False
    
    if 'E' not in word:
       return False
    
    if word[2] == 'E' or word[4] == 'E':
        return False
    
    return True

secret = 'MOWER'
tries = 0

while tries < 6:
    guess = input("Enter your guess: ").upper()
    tries += 1

    if not check_word(guess):
        print("Guess does not meet guidelines.")
        continue
    if guess == secret:
        print("Correct!")
        break
    else:
        print("Not correct.")

print(f"Tries used: {tries}/6")
# Out:
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Tries used: 6/6

# %% [markdown]
# You can use any of the functions from the previous chapter, like `uses_any`.

# %% [markdown]
# You can use the following loop to test your function.

# %% [markdown]
# ### Exercise
#
# Continuing the previous exercise, suppose you guess the work `TOTEM` and learn that the `E` is *still* not in the right place, but the `M` is. How many words are left?

# %%
def check_word(word):
    word = word.upper()

    if len(word) != 5:
        return False
    
    forbidden_letters = ['S', 'P', 'A', 'D', 'C', 'L', 'R', 'K', 'T', 'O']
    if any(letter in forbidden_letters for letter in word):
        return False
    
    if word[4] != 'M':
        return False
    
    if 'E' not in word:
        return False
    
    if word[2] == 'E' or word[3] == 'E' or word[4] == 'E':
        return False
    
    return True

secret = 'MOWER'
tries = 0

while tries < 6:
    guess = input("Enter your guess: ").upper()
    tries += 1

    if not check_word(guess):
        print("Guess does not meet guidelines.")
        continue
    if guess == secret:
        print("Correct!")
        break
    else:
        print("Not correct.")

print(f"Tries used: {tries}/6")
# Out:
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Guess does not meet guidelines.
# Tries used: 6/6

# %% [markdown]
# ### Exercise
#
# *The Count of Monte Cristo* is a novel by Alexandre Dumas that is considered a classic.
# Nevertheless, in the introduction of an English translation of the book, the writer Umberto Eco confesses that he found the book to be "one of the most badly written novels of all time".
#
# In particular, he says it is "shameless in its repetition of the same adjective," and mentions in particular the number of times "its characters either shudder or turn pale."
#
# To see whether his objection is valid, let's count the number number of lines that contain the word `pale` in any form, including `pale`, `pales`, `paled`, and `paleness`, as well as the related word `pallor`.
# Use a single regular expression that matches any of these words.
# As an additional challenge, make sure that it doesn't match any other words, like `impale` -- you might want to ask a virtual assistant for help.

# %% [markdown]
# The following cell downloads the book from Project Gutenberg <https://www.gutenberg.org/ebooks/1184>.

# %%
import re

pattern = re.compile(r"\bpal(?:e|es|ed|eness|lor)\b", re.IGNORECASE)

count = 0
matching_lines = []

with open("C:\\Users\\nmolendyk1\\Documents\\GitHub\\oim3640\data\pg1184.txt") as f:
    for line_number, line in enumerate(f, start=1):
        if pattern.search(line):
            count += 1
            matching_lines.append((line_number, line.strip()))

print(f"Number of matching lines: {count}")

# Optional: print the lines themselves
for ln, text in matching_lines:
    print(f"{ln}: {text}")
# Out:
# Number of matching lines: 226
# 650: fell into his arms, pale and trembling.
# 697: “What, no wine?” said Dantès, turning pale, and looking alternately at
# 1173: Fernand, pale and trembling, drew back, like a traveller at the sight
# 1180: rather the expression of sorrow. Suddenly Edmond saw the gloomy, pale,
# 1215: Fernand became deadly pale. “But you are deceived, Edmond,” she
# 1473: then, turning round, he perceived Fernand, who had fallen, pale and
# 1875: that such a being as himself existed, was pale and abstracted;
# 1912: direst torture on him, for his lips became ghastly pale, and even
# 1978: “In an hour?” inquired Danglars, turning pale. “How is that, my
# 2042: Fernand’s paleness appeared to have communicated itself to Danglars. As
# 2065: ghastly pale.
# 2284: his pale agitated lips, and a convulsive spasm passed over his
# 2292: at the door. He was very pale.
# 2309: A despairing cry escaped the pale lips of Mercédès; the old man sank
# 2735: of life. The prisoner whom you there see pale, agitated, and alarmed,
# 2745: “For shame, M. de Villefort!” said Renée, becoming quite pale; “don’t
# 2769: pale, agitated, and as though beaten out of all composure by the fire
# 2907: “How dreadful!” exclaimed Renée, turning pale.
# 3114: instant after Dantès entered. He was pale, but calm and collected, and
# 3333: more pale.
# 4048: the altar of his father’s faults, appeared to him pale and threatening,
# 4543: of police appeared at the door, pale, trembling, and as if ready to
# 4647: “So then,” he exclaimed, turning pale with anger, “seven conjoined and
# 4772: hung on the speaker’s lips, turned alternately red and pale. The king
# 4926: “It is he!” said Villefort, turning pale.
# 5265: trying conversation. Villefort, pale and agitated, ran to the window,
# 7672: but Fernand looked pale and agitated.”
# 8057: standing in the middle of the room, pale as death, his forehead
# 8287: your paleness and agitation what is passing in your heart at this
# 8351: me, who have grown pale over them by many nights’ study, and have
# 8499: attentions. Spada turned pale, as Cæsar looked at him with an ironical
# 8925: Dantès saw the old man, pale, but yet erect, clinging to the bedstead.
# 9072: feeble ray came into the dungeon, and paled the ineffectual light of
# 9258: On the bed, at full length, and faintly illuminated by the pale light
# 10007: from the sun, had now that pale color which produces, when the features
# 10314: high,” played in floods of pale light on the rocky hills of this second
# 10473: moaning and turning pale.
# 10685: Anyone else would have rushed on with a cry of joy. Dantès turned pale,
# 10827: Dantès found nothing he could not have become more ghastly pale.
# 11332: Radelle, was pale, meagre, and sickly-looking. Born in the neighborhood
# 11558: A deadly pallor followed the flush on the countenance of Caderousse,
# 12095: him so pale and haggard, that believing him very ill, I went and told
# 12132: his seat, with red eyes and pale cheeks.
# 12599: Caderousse started and turned pale.
# 13095: The young girl turned pale and continued to descend, while the stranger
# 13176: At this almost brutal speech Morrel turned deathly pale.
# 13246: “Oh, my God!” cried Morrel, turning pale, “what is it?”
# 13697: Julie saw the latter leave it pale, trembling, and his features
# 13789: in his pale and careworn visage. They did not dare to ask him how he
# 13930: “Father,” he exclaimed, turning pale as death, “what are you going to
# 14884: Although of a paleness that was almost livid, this man had a remarkably
# 14890: His pallor was so peculiar, that it seemed to pertain to one who had
# 15284: chamber of statues, lighted only by one of those pale and antique lamps
# 16155: the other with the pallor of death on his brow. A terrible battle
# 16238: firelight, the unearthly pallor of the young girl and of Diavolaccio.
# 16243: the unearthly pallor in the young girl and the bandit. A knife was
# 16290: with terror on Rita, pale and bloody, a knife buried in her bosom. A
# 16296: whole band.’ The old man spoke not, and grew pale as death. ‘Now,’
# 16498: glanced at Luigi, and each time she saw that he was pale and that his
# 16975: openings of which the pale moonlight played and flickered like the
# 17717: ours, than anything human. How ghastly pale he is!”
# 17765: burning,—the same ghastly paleness. Then observe, too, that the woman
# 17866: or Humann. He was rather too pale, certainly; but then, you know,
# 17867: paleness is always looked upon as a strong proof of aristocratic
# 18761: unmoved—nay, more, a slight color seemed striving to rise in his pale
# 18902: water, of which, to judge from his pallor, he stood in great need; and
# 18959: equalled the pallor of his own face. Their toilet finished, they
# 19539: Franz had by degrees become accustomed to the count’s pallor, which had
# 19542: rather the principal quality of which was the pallor. Truly, a Byronic
# 20300: with its pale and flickering flame the singular scene which presented
# 21827: pace forward, and a slight tinge of red colored his pale cheeks.
# 22481: was so faint in the room that Albert did not perceive the pallor that
# 22711: husband had entered, pale and motionless; when Monte Cristo turned
# 22835: now were so pale as you came into the room——”
# 22837: “Was I pale, Albert?”
# 22839: “Yes; a pallor that suits you admirably, mother, but which did not the
# 22941: and his brow, though so pale, is free from wrinkles,—he is not only
# 23096: At these words Bertuccio turned pale.
# 23438: not let fall the lantern, the light showed his pale and altered
# 23457: It is a bad sign; a quiet conscience does not occasion such paleness in
# 23843: glimpses of the pale moon, hidden momentarily by masses of dark clouds
# 24251: feeble step. ‘What do you say?’ asked his wife, pale as death.
# 24569: pale and breathless into his chair.
# 24766: “The man was Caderousse—he was pale and his shirt was all bloody.
# 25270: spoke, Ali turned pale and held down his head.
# 25934: undertone. Madame Danglars turned very pale, then exclaimed:
# 26188: deadly pale he is! My child, my darling Edward; speak to your
# 26198: reached them, ere the boy, though still pale as marble, opened his
# 26273: small for his age, and unnaturally pale. A mass of straight black hair,
# 26291: Madame de Villefort became very pale, and, seizing her son’s arm, drew
# 26529: slender he had now become meagre; once pale, he was now yellow; his
# 27417: “No, no,” returned Monte Cristo, pale as death, pressing one hand on
# 27598: At these words the count’s paleness, which had for some time been
# 28223: Madame de Villefort at this really did turn pale, and was very nearly
# 29070: contrasting vividly with her naturally pale complexion. But that which
# 29447: observe him sooner; “the count?—oh, he is so dreadfully pale.”
# 29450: pallor is what we want to find out. The Countess G—— insists upon it
# 29715: perceived his pale features close to Morcerf’s face. It was as if the
# 29733: Danglars’ box. Upon his return to Haydée he found her still very pale.
# 31145: “I agree with you, monsieur,” said the young man, turning pale, and, in
# 31793: immediate return.” Valentine turned pale, and leaned her hand against
# 33982: The man looked at the bank-notes, felt them, counted them, turned pale,
# 34182: After his wife the banker descended, as pale as though he had issued
# 34664: It was Morrel’s turn to become pale.
# 34722: with their pale lips and staring eyes, ‘We have seen’?”
# 34766: “Ah, madame,” cried Debray, “what is the matter with you? how pale you
# 35066: me back.” Andrea turned pale, but said nothing.
# 35792: had been pronounced; but then she became pale, and, rising, as if
# 35974: “Oh,” said Danglars, becoming very pale, how you are running on!”
# 36593: saw the pale moon shedding a long stream of white light on the spiral
# 36823: pale.
# 36969: Monte Cristo turned pale, and looked at Albert, while playing with some
# 37954: the attention,—it was his pale complexion, his waving black hair, his
# 38097: “Indeed?” said Danglars, becoming pale.
# 38155: obstinately refused. Albert rejoined his mother; she was very pale.
# 38275: The count became pale as death, the blood rushed to his heart, and then
# 38595: daughter from Madame de Morcerf’s. He was so pale when he appeared at
# 39022: pale and trembling to the gate under the chestnut-trees.
# 39069: strength and courage to my support. Perhaps I turned pale and trembled,
# 39252: He drew near with his sweet smile, and but for his paleness one might
# 39308: pale with joy extended both hands towards Valentine through the
# 39808: moon shone upon his face, which was so pale it might have been taken
# 39821: mantle-piece threw some of its pale rays without, and a shadow was seen
# 40380: “Extremely,” replied he; “she looked so pale this morning, I scarcely
# 40538: family, for she was pale and looked fatigued. She sat down, took Edward
# 40544: whole party was assembled. Valentine was so pale one might trace the
# 40610: Valentine rose, pale and dumb as a statue. Albert and Château-Renaud
# 40964: very pale; he looked round him a second time, several members of the
# 41031: trembling pallor these details of his father’s death, which had
# 41098: when Valentine, pale with emotion, had wiped away a tear; when
# 42221: startling and ominous,” said Haydée, shaking her head and turning pale
# 42329: me, I can never forget the pale complexion and black eyes of the young
# 42497: emotion that the perspiration stood upon her pale brow, and her stifled
# 42540: and, intoxicated by their crime, though still pale with fear, they
# 42612: paleness of Haydée’s countenance, “and I reproach myself now for having
# 42739: appear, pale and trembling, to forbid the signing of the contract, like
# 43002: Morcerf, turning pale with anger. The expression of the count’s face
# 43928: distant corner of the room remained half hidden behind a curtain. Pale
# 43949: face became pale and his hair seemed to stand on end, he sprang towards
# 43971: second glance was at the dying man. She turned pale, and her eye passed
# 44522: daughter Madeleine were concerned.” The doctor turned pale. “Doctor,
# 44545: daughter—if I should come one day, pale as a spectre, and say to you,
# 44761: Andrea turned pale, but as it was dark his pallor was not perceptible.
# 45072: Andrea did more than tremble this time, he turned pale.
# 45804: immediately a pale light, just bright enough to render objects
# 46564: Bertuccio alone turned pale whenever Benedetto’s name was mentioned in
# 46694: Albert turned frightfully pale; he endeavored to speak, but the words
# 47484: Yanina and Colonel Fernand, he turned so frightfully pale that every
# 47651: pale, and clenched his hands on the papers he held. The committee
# 47659: “The president paused, and the count turned pale. The president looked
# 47744: A greenish pallor spread over the count’s cheeks, and his eyes became
# 48041: Danglars turned pale; Cavalcanti moved a step forward, and Albert
# 48067: “Sir,” replied Danglars, pale with anger and fear, “I warn you, when I
# 48286: of his mother’s bed. It was evident from his pale face and knit brows
# 48329: “I?” said Mercédès, blushing as rapidly as she had turned pale, and
# 48392: The count, in his survey of the pit, encountered a pale face and
# 48405: The door opened, and Monte Cristo, turning round, saw Albert, pale and
# 48984: “Edmond,” continued she, “you will see that if my face is pale, if my
# 49085: shone upon the pale blue paper on which he had just inscribed his
# 49161: sweet pale face, those lovely eyes closed, that beautiful form
# 49255: the club. At each shot Morrel turned pale. He examined the bullets with
# 49454: servant’s arms, and joined them. He was pale, and his eyes were red and
# 49657: As he alighted, he thought he saw his father’s pale face behind the
# 49833: Albert stood pale and motionless to hear what his mother would decide
# 50037: leave everything in perfect order, she did not perceive a pale and
# 50041: Madame de Morcerf’s apartments. From that glass door the pale-faced man
# 50120: “That may be,” said the count, turning pale; “but you know the guilty
# 50189: The Count of Monte Cristo turned dreadfully pale; his eye seemed to
# 50334: beautiful, but her usual pallor had increased; her eyes were more
# 50352: water; I left half, because it seemed so bitter.” Noirtier turned pale,
# 50510: “Yes, look at yourself in that glass; you have turned pale and then red
# 50513: “Indeed,” cried Eugénie, “you are very pale!”
# 50584: Barrois, ran in at the same moment. Valentine was so pale, so cold, so
# 50680: “What is the matter, Maximilian?” asked he; “you are pale, and the
# 50763: “This is a gloomy introduction, if I may judge from your pallor and
# 50791: extreme emotion helped him to disguise a blush, or his pallor, or the
# 50847: sleep on, if they are asleep; let them grow pale in their drowsiness,
# 50972: scarcely discernible, they were so pale and white, as well as her whole
# 50999: and become round, his cheeks turn pale and tremble; the perspiration
# 51286: “Unhappy girl, unhappy girl!” murmured Danglars, turning pale, for he
# 51416: “Then,” said Danglars, pale with anger, which was not at all due to
# 51837: lips turned pale, but who preserved his ceremonious smile, Andrea
# 51905: noticeable because of its contrast with the deadly paleness of his
# 51999: Andrea turned pale, and drew towards the door; he saw a cloud rising in
# 52034: slightly pale; Andrea reached the anteroom beyond the little
# 52234: Hercules, and you only the pale Omphale!”
# 52666: A pallor overspread the young man’s forehead, and he looked around him
# 52831: “For pity’s sake,” he cried, pale and bewildered, without seeing whom
# 52869: his body a little thrown back, pale, and with the useless knife in his
# 53188: “You know that you are, madame,” said Villefort, whose pale cheeks
# 53256: dwelling?’” The baroness became pale. “You were saying this, were you
# 53370: Madame Danglars rose from her seat, pale and cold.
# 54047: who were on the same floor had entered, and seeing Valentine pale and
# 54139: The two men turned round, and saw Morrel standing at the door, pale and
# 54153: place, but his eyes expressed alarm, which was confirmed by the pallor
# 54167: answered. He turned towards Noirtier; the pallor and anguish expressed
# 54216: disordered bed, and the pale corpse of the young girl who was lying on
# 54236: other faculty. That pale face and flaming glance appeared to Villefort
# 54511: entered the room alone. Noirtier was near the bed, pale, motionless,
# 54528: the corpse in chloride of lime, he uncovered the calm and pale face,
# 54952: Danglars again became pale, and hastened to conduct the count out.
# 55267: “How pale he is!” said Château-Renaud, shuddering.
# 55982: The dread with which the pale and motionless baroness listened to this,
# 56047: certificate and check into her pocket-book, and then, standing pale and
# 56477: seen,—pacing to and fro from morning till night, pale, careworn, and
# 56896: Villefort became pale; he understood the old man’s meaning.
# 57016: Villefort remained silent for a moment, and dented his pale cheeks with
# 57039: At the door he paused for a moment to wipe his damp, pale brow. He then
# 57048: “but how pale you are! Have you been working all night? Why did you not
# 57068: The child, unaccustomed to such treatment, arose, pale and trembling;
# 57091: her, while she became deadly pale.
# 57112: frightful pallor of that woman, the anguish of her look, the trembling
# 57691: first pale, had become red and burning; then he suddenly arose and
# 57888: under a violent attack of fever, and yet he was deadly pale.
# 58068: boudoir, Madame de Villefort was standing erect, pale, her features
# 58132: cheeks, but they were icy cold and pale; he felt the stiffened limbs;
# 58244: Monte Cristo became pale at this horrible sight; he felt that he had
# 58264: and Monte Cristo reappeared. Pale, with a dull eye and heavy heart, all
# 59934: burnt. His agitated features presented the appearance of pale and
# 60431: “Suffer hunger?” said Danglars, becoming pale.
# 60537: “The Count of Monte Cristo!” said Danglars, more pale from terror than
# 60983: two rooms. Pale, and sweetly smiling, she looked like an angel of mercy
# 61038: Monte Cristo turned around; Haydée was standing pale, motionless,
# 61046: Haydée became pale, and lifting her transparent hands to heaven,
# 61057: Morrel on her shoulder, “do you not see how pale she is? Do you not see
# 61198: she became pale, a heavy sigh escaped from her bosom, and tears, not

# %% [markdown]
# The following cell runs a function that reads the file from Project Gutenberg and writes a file that contains only the text of the book, not the added information about the book.

# %% [markdown]
# By this count, these words appear on `223` lines of the book, so Mr. Eco might have a point.

# %% [markdown]
# [Think Python: 3rd Edition](https://allendowney.github.io/ThinkPython/index.html)
#
# Copyright 2024 [Allen B. Downey](https://allendowney.com)
#
# Code license: [MIT License](https://mit-license.org/)
#
# Text license: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
